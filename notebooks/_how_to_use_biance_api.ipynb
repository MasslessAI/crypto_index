# %%
import sys
sys.path.append('../')
import binance
from binance.client import Client
from binance.enums import *

# %%
api_key = 'vmPUZE6mv9SD5VNHk4HlWFsOr6aKE2zvsw0MuIgwCIPy6utIco14y7Ju91duEh8A'
api_secret = 'NhqPtmdSJYdKjVHjA7PZj4Mge3R5YNiP1e3UZjInClVN65XAbvqqM6A7H5fATj0j'
client = Client(api_key, api_secret)

# %%
client.ping()

# %%
time_res = client.get_server_time()
print(time_res)

# %%
status = client.get_system_status()
print(status)

# %%
info = client.get_exchange_info()
print(info)
# Out:
# {'serverTime': 1540523679778}
# {'msg': 'normal', 'status': 0}
# {'timezone': 'UTC', 'serverTime': 1540523680143, 'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT', 'interval': 'MINUTE', 'limit': 1200}, {'rateLimitType': 'ORDERS', 'interval': 'SECOND', 'limit': 10}, {'rateLimitType': 'ORDERS', 'interval': 'DAY', 'limit': 100000}], 'exchangeFilters': [], 'symbols': [{'symbol': 'ETHBTC', 'status': 'TRADING', 'baseAsset': 'ETH', 'baseAssetPrecision': 8, 'quoteAsset': 'BTC', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00312300', 'maxPrice': '0.31220500', 'tickSize': '0.00000100'}, {'filterType': 'LOT_SIZE', 'minQty': '0.00100000', 'maxQty': '100000.00000000', 'stepSize': '0.00100000'}, {'filterType': 'MIN_NOTIONAL', 'minNotional': '0.00100000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}, {'symbol': 'LTCBTC', 'status': 'TRADING', 'baseAsset': 'LTC', 'baseAssetPrecision': 8, 'quoteAsset': 'BTC', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00080700', 'maxPrice': '0.08069000', 'tickSize': '0.00000100'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01000000', 'maxQty': '100000.00000000', 'stepSize': '0.01000000'}, {'filterType': 'MIN_NOTIONAL', 'minNotional': '0.00100000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}, {'symbol': 'BNBBTC', 'status': 'TRADING', 'baseAsset': 'BNB', 'baseAssetPrecision': 8, 'quoteAsset': 'BTC', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00014980', 'maxPrice': '0.01497600', 'tickSize': '0.00000010'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01000000', 'maxQty': '90000000.00000000', 'stepSize': '0.01000000'}, {'filterType': 'MIN_NOTIONAL', 'minNotional': '0.00100000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}, {'symbol': 'NEOBTC', 'status': 'TRADING', 'baseAsset': 'NEO', 'baseAssetPrecision': 8, 'quoteAsset': 'BTC', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00025500', 'maxPrice': '0.02542000', 'tickSize': '0.00000100'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01000000', 'maxQty': '100000.00000000', 'stepSize': '0.01000000'}, {'filterType': 'MIN_NOTIONAL', 'minNotional': '0.00100000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}, {'symbol': 'QTUMETH', 'status': 'TRADING', 'baseAsset': 'QTUM', 'baseAssetPrecision': 8, 'quoteAsset': 'ETH', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00200800', 'maxPrice': '0.20080000', 'tickSize': '0.00000100'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01000000', 'maxQty': '90000000.00000000', 'stepSize': '0.01000000'}, {'filterType': 'MIN_NOTIONAL', 'minNotional': '0.01000000'}, {'filterType': 'ICEBERG_PARTS', 'limit': 10}, {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]}, {'symbol': 'EOSETH', 'status': 'TRADING', 'baseAsset': 'EOS', 'baseAssetPrecision': 8, 'quoteAsset': 'ETH', 'quotePrecision': 8, 'orderTypes': ['LIMIT', 'LIMIT_MAKER', 'MARKET', 'STOP_LOSS_LIMIT', 'TAKE_PROFIT_LIMIT'], 'icebergAllowed': True, 'filters': [{'filterType': 'PRICE_FILTER', 'minPrice': '0.00266500', 'maxPrice': '0.26641000', 'tickSize': '0.00000100'}, {'filterType': 'LOT_SIZE', 'minQty': '0.01000000', 'maxQty': '90000000.00000000', 'stepSize': '0.01000000'}, {' ...

# %%
### The authentication info is only a mock
### otherwise this is a functioning call
order = client.create_order(
    symbol='BNBBTC',
    side=SIDE_BUY,
    type=ORDER_TYPE_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=100,
    price='0.00001')

order = client.order_limit_buy(
    symbol='BNBBTC',
    quantity=100,
    price='0.00001')

order = client.order_limit_sell(
    symbol='BNBBTC',
    quantity=100,
    price='0.00001')
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# <ipython-input-22-8fc111248bee> in <module>()
#       5     timeInForce=TIME_IN_FORCE_GTC,
#       6     quantity=100,
# ----> 7     price='0.00001')
#       8
#       9 order = client.order_limit_buy(
#
# ~\OneDrive\Documents\GitHub\python_biance\python-binance\binance\client.py in create_order(self, **params)
#    1131
#    1132         """
# -> 1133         return self._post('order', True, data=params)
#    1134
#    1135     def order_limit(self, timeInForce=TIME_IN_FORCE_GTC, **params):
#
# ~\OneDrive\Documents\GitHub\python_biance\python-binance\binance\client.py in _post(self, path, signed, version, **kwargs)
#     207
#     208     def _post(self, path, signed=False, version=PUBLIC_API_VERSION, **kwargs):
# --> 209         return self._request_api('post', path, signed, version, **kwargs)
#     210
#     211     def _put(self, path, signed=False, version=PUBLIC_API_VERSION, **kwargs):
#
# ~\OneDrive\Documents\GitHub\python_biance\python-binance\binance\client.py in _request_api(self, method, path, signed, version, **kwargs)
#     178         uri = self._create_api_uri(path, signed, version)
#     179
# --> 180         return self._request(method, uri, signed, **kwargs)
#     181
#     182     def _request_withdraw_api(self, method, path, signed=False, **kwargs):
#
# ~\OneDrive\Documents\GitHub\python_biance\python-binance\binance\client.py in _request(self, method, uri, signed, force_params, **kwargs)
#     173
#     174         response = getattr(self.session, method)(uri, **kwargs)
# --> 175         return self._handle_response(response)
#     176
#     177     def _request_api(self, method, path, signed=False, version=PUBLIC_API_VERSION, **kwargs):
#
# ~\OneDrive\Documents\GitHub\python_biance\python-binance\binance\client.py in _handle_response(self, response)
#     197         """
#     198         if not str(response.status_code).startswith('2'):
# --> 199             raise BinanceAPIException(response)
#     200         try:
#     201             return response.json()
#
# BinanceAPIException: APIError(code=-2015): Invalid API-key, IP, or permissions for action.
