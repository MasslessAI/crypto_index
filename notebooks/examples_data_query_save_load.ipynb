# %%
import sys
sys.path.append('../')

import cqt.datagen as dg
import pandas as pd
import pickle

from datetime import timedelta

# %%
key = '4A2F2B3F-B60E-4FFB-919B-D452A8022E69'
source = 'coinapi'

# %%
request_btc = {'request_type' : 'ohlcv', \
               'symbol_id' : 'GEMINI_SPOT_BTC_USD', \
               'period_id' : '1DAY', \
               'time_start' : '2017-08-29T10:23:14', \
               'limit' : '100000'}

df_btc = dg.data_gen(source, request_btc, key, True)
df_btc.data.head()
# Out:
#    price_close  price_open  price_high  price_low  \
# 0      4583.85     4590.00     4641.43    4495.05
# 1      4736.28     4583.00     4762.76    4579.91
# 2      4924.00     4736.28     4924.00    4709.28
# 3      4642.85     4924.00     4985.00    4505.00
# 4      4607.47     4643.63     4740.41    4460.05
#
#                      time_close                     time_open  trades_count  \
# 0  2017-08-30T23:59:10.1240000Z  2017-08-30T00:00:00.8210000Z         14313
# 1  2017-08-31T23:59:57.7490000Z  2017-08-31T00:00:12.3180000Z         11407
# 2  2017-09-01T23:59:37.9730000Z  2017-09-01T00:00:11.4080000Z         11470
# 3  2017-09-02T23:59:51.6230000Z  2017-09-02T00:00:17.9900000Z         20976
# 4  2017-09-03T23:57:28.9910000Z  2017-09-03T00:00:00.0920000Z         12831
#
#    volume_traded request_type            symbol_id period_id  \
# 0    8832.814987        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 1    7268.196353        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 2    8188.879244        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 3   13402.051241        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 4    9479.341778        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
#
#             time_start   limit
# 0  2017-08-29T10:23:14  100000
# 1  2017-08-29T10:23:14  100000
# 2  2017-08-29T10:23:14  100000
# 3  2017-08-29T10:23:14  100000
# 4  2017-08-29T10:23:14  100000

# %%
request_eth = {'request_type' : 'ohlcv', \
               'symbol_id' : 'GEMINI_SPOT_ETH_USD', \
               'period_id' : '1DAY', \
               'time_start' : '2017-08-29T00:00:00', \
               'limit' : '100000'}

df_eth = dg.data_gen(source, request_eth, key, True)
df_eth.data.head()
# Out:
#    price_close  price_open  price_high  price_low  \
# 0       372.02      360.99      374.35     360.00
# 1       384.00      371.50      390.85     368.00
# 2       388.48      383.70      390.01     380.00
# 3       392.13      388.52      397.24     387.41
# 4       354.39      392.13      393.21     333.00
#
#                      time_close                     time_open  trades_count  \
# 0  2017-08-29T23:59:36.0860000Z  2017-08-29T13:21:39.9970000Z          7347
# 1  2017-08-30T23:59:39.8180000Z  2017-08-30T00:01:34.8770000Z         12597
# 2  2017-08-31T23:59:36.6130000Z  2017-08-31T00:00:07.5790000Z          8421
# 3  2017-09-01T23:59:27.2560000Z  2017-09-01T00:00:45.1170000Z          8502
# 4  2017-09-02T23:59:57.2860000Z  2017-09-02T00:00:14.2870000Z         20108
#
#    volume_traded request_type            symbol_id period_id  \
# 0   74369.788391        ohlcv  GEMINI_SPOT_ETH_USD      1DAY
# 1  143278.714149        ohlcv  GEMINI_SPOT_ETH_USD      1DAY
# 2  105732.317280        ohlcv  GEMINI_SPOT_ETH_USD      1DAY
# 3   84372.665620        ohlcv  GEMINI_SPOT_ETH_USD      1DAY
# 4  199243.326888        ohlcv  GEMINI_SPOT_ETH_USD      1DAY
#
#             time_start   limit
# 0  2017-08-29T00:00:00  100000
# 1  2017-08-29T00:00:00  100000
# 2  2017-08-29T00:00:00  100000
# 3  2017-08-29T00:00:00  100000
# 4  2017-08-29T00:00:00  100000

# %%
print(df_btc.file_name)
print(df_eth.file_name)
# Out:
# coinapi_ohlcv_GEMINI_SPOT_BTC_USD_1DAY_data
# coinapi_ohlcv_GEMINI_SPOT_ETH_USD_1DAY_data

# %%
file_btc = open('../data/pickle/' + df_btc.file_name + '.pickle','rb')
df_btc_reload = pickle.load(file_btc)

# %%
df_btc_reload.data.head()
# Out:
#    price_close  price_open  price_high  price_low  \
# 0      4583.85     4590.00     4641.43    4495.05
# 1      4736.28     4583.00     4762.76    4579.91
# 2      4924.00     4736.28     4924.00    4709.28
# 3      4642.85     4924.00     4985.00    4505.00
# 4      4607.47     4643.63     4740.41    4460.05
#
#                      time_close                     time_open  trades_count  \
# 0  2017-08-30T23:59:10.1240000Z  2017-08-30T00:00:00.8210000Z         14313
# 1  2017-08-31T23:59:57.7490000Z  2017-08-31T00:00:12.3180000Z         11407
# 2  2017-09-01T23:59:37.9730000Z  2017-09-01T00:00:11.4080000Z         11470
# 3  2017-09-02T23:59:51.6230000Z  2017-09-02T00:00:17.9900000Z         20976
# 4  2017-09-03T23:57:28.9910000Z  2017-09-03T00:00:00.0920000Z         12831
#
#    volume_traded request_type            symbol_id period_id  \
# 0    8832.814987        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 1    7268.196353        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 2    8188.879244        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 3   13402.051241        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
# 4    9479.341778        ohlcv  GEMINI_SPOT_BTC_USD      1DAY
#
#             time_start   limit
# 0  2017-08-29T10:23:14  100000
# 1  2017-08-29T10:23:14  100000
# 2  2017-08-29T10:23:14  100000
# 3  2017-08-29T10:23:14  100000
# 4  2017-08-29T10:23:14  100000
