# %%
import sys
sys.path.append('../')

import cii
import cii.datagen as dg
import cii.model as md
import cii.portfolio as pfo
import cii.strategy as stg
import pandas as pd

from datetime import datetime
from datetime import timedelta
import matplotlib.pyplot as plt

# %%
df_btc = pd.read_csv('..\data\coinapi_ohlcv_GEMINI_SPOT_BTC_USD_1DAY_data.csv')
df_eth = pd.read_csv('..\data\coinapi_ohlcv_GEMINI_SPOT_ETH_USD_1DAY_data.csv')

# %%
df_btc = dg.convert_coinapi_data(df_btc)
df_eth = dg.convert_coinapi_data(df_eth)
df_btc.head()
# Out:
#    price_close  price_open  price_high  price_low  \
# 0      4591.38     4431.66     4705.07    4431.65
# 1      4583.85     4590.00     4641.43    4495.05
# 2      4736.28     4583.00     4762.76    4579.91
# 3      4924.00     4736.28     4924.00    4709.28
# 4      4642.85     4924.00     4985.00    4505.00
#
#                      time_close                     time_open  trades_count  \
# 0  2017-08-30T00:00:00.0000000Z  2017-08-29T00:00:00.0000000Z          8315
# 1  2017-08-31T00:00:00.0000000Z  2017-08-30T00:00:00.0000000Z         14313
# 2  2017-09-01T00:00:00.0000000Z  2017-08-31T00:00:00.0000000Z         11407
# 3  2017-09-02T00:00:00.0000000Z  2017-09-01T00:00:00.0000000Z         11470
# 4  2017-09-03T00:00:00.0000000Z  2017-09-02T00:00:00.0000000Z         20976
#
#    volume_traded
# 0    6005.454508
# 1    8832.814987
# 2    7268.196353
# 3    8188.879244
# 4   13402.051241

# %%
model_config = {'asset_type': 'spot'}
model_btc = md.AssetModelComponent('btc', df_btc, model_config)
model_eth = md.AssetModelComponent('eth', df_eth, model_config)
model_btc.plot_price()
model_eth.plot_price()
asset_model = md.AssetModel([])
asset_model.insert_component(model_btc)
asset_model.insert_component(model_eth)
price_btc_eth = asset_model.concat_prices('btc','eth')
logret_btc_eth = asset_model.concat_log_return('btc','eth', '1d')
print('corr is', asset_model.corr_log_return('btc', 'eth', '1d'))
# Out:
# corr is 0.629184386291

# %%
bb_rule = {'method' : 'moving_average', 'window_size' : 3, 'tolerance_up' : 0.0, 'tolerance_down' : 0.03}

# %%
cash = 100000
assets = {'btc': 0, 'eth': 0}
ini_pfo = pfo.Portfolio(assets, cash)
strats = stg.StrategyBearBull(asset_model, ini_pfo, bb_rule)

# %%
start_date_str = '2018-01-01'
start_date = datetime.strptime(start_date_str, '%Y-%m-%d')
report = strats.back_testing(start_date)
print(report)
# Out:
#           date        total         pnl         cash  btc_holding  btc_price  \
# 0   2018-01-01  100000.0000      0.0000  100000.0000         0.00   13820.26
# 1   2018-01-02  100000.0000      0.0000  100000.0000         0.00   13338.41
# 2   2018-01-03  100000.0000      0.0000  100000.0000         0.00   14740.09
# 3   2018-01-04  100000.0000      0.0000   56259.4000         1.65   15144.00
# 4   2018-01-05  100249.5895    249.5895   31716.0260         2.57   15199.99
# 5   2018-01-06  105371.3407   5121.7512   17946.4999         3.03   16945.50
# 6   2018-01-07  107429.3239   2057.9832   17946.4999         3.03   17175.00
# 96  2018-04-07   96036.9875      0.0000   96036.9875         0.00    6592.94
# 97  2018-04-08   96036.9875      0.0000   96036.9875         0.00    6895.99
# 98  2018-04-09   96036.9875      0.0000   96036.9875         0.00    7022.72
# 99  2018-04-10   96036.9875      0.0000   96036.9875         0.00    6771.01
# 100 2018-04-11   96036.9875      0.0000   96036.9875         0.00    6830.68
# 101 2018-04-12   96036.9875      0.0000   96036.9875         0.00    6939.43
# 102 2018-04-13   96036.9875      0.0000   96036.9875         0.00    7920.39
# 103 2018-04-14   96036.9875      0.0000   54073.8019         3.04    7875.94
# 104 2018-04-15   96663.3566    626.3691   30422.4658         4.73    7998.07
# 105 2018-04-16  100161.4897   3498.1331   30422.4658         4.73    8357.43
# 106 2018-04-17   97444.6922  -2716.7975   30422.4658         4.73    8052.27
# 107 2018-04-18   96180.1924  -1264.4998   30422.4658         4.73    7890.30
# 108 2018-04-19   98766.3340   2586.1416   30422.4658         4.73    8167.00
# 109 2018-04-20  101569.5830   2803.2490   30422.4658         4.73    8269.30
# 110 2018-04-21  107173.3626   5603.7796   30422.4658         4.73    8847.07
#
#      eth_holding  eth_price
# 0           0.00     736.11
# 1           0.00     750.77
# 2           0.00     859.98
# 3          19.95     940.00
# 4          31.09     947.88
# 5          37.26     968.33
# 6          37.26    1004.90
# 7          37.26    1115.11
# 8          37.26    1135.25
# 9          37.26    1292.25
# 10         37.26    1251.81
# 11         37.26    1139.00
# 12         37.26    1259.74
# 13         37.26    1381.81
# 14         37.26    1360.53
# 15         37.26    1274.09
# 16         37.26    1065.01
# 17          0.00    1026.60
# 18          0.00    1024.11
# 19          0.00    1039.82
# 20          0.00    1149.68
# 21          0.00    1049.92
# 22          0.00     998.00
# 23          0.00     986.19
# 24          0.00    1060.00
# 25          0.00    1044.00
# 26          0.00    1048.00
# 27          0.00    1106.00
# 28          0.00    1223.60
# 29          0.00    1165.00
# ..           ...        ...
# 81          0.00     539.49
# 82          0.00     543.00
# 83          0.00     519.86
# 84          0.00     522.57
# 85          0.00     486.22
# 86          0.00     449.77
# 87          0.00     445.52
# 88          0.00     382.42
# 89          0.00     393.81
# 90          0.00     393.84
# 91          0.00     378.55
# 92          0.00     384.94
# 93          0.00     415.49
# 94          0.00     378.05
# 95          0.00     380.99
# 96          0.00     370.20
# 97          0.00     384.92
# 98          0.00     400.94
# 99          0.00     398.88
# 100         0.00     415.00
# 101         0.00     429.98
# 102         0.00     494.14
# 103        36.39     495.20
# 104        56.57     502.21
# 105        56.57     534.00
# 106        56.57     511.49
# 107        56.57     502.68
# 108        56.57     525.26
# 109        56.57     566.26
# 110        56.57     617.01
#
# [111 rows x 8 columns]

# %%
plt.plot(report['date'], report['total'])
plt.show()
plt.plot(report['date'], report['pnl'])
plt.show()
plt.plot(report['date'], report['btc_price'])
plt.show()
plt.plot(report['date'], report['eth_price'])
plt.show()
